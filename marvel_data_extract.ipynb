# %% [markdown]
#  Getting Marvel Data from Wikipedia Web Page

# %%
# %pip install pandas

# %pip install requests

# %pip install beautifulsoup4

# %pip install python-dotenv

# %pip install boto3

# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup
import re
from dotenv import load_dotenv
import boto3
import base64

# %%
wiki_url = "https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films"
response = requests.get(wiki_url)
var = BeautifulSoup(response.content, 'html.parser')
table = var.find_all('table', class_='wikitable')

# %%
column = []
for tbl in table[:1]:
    header_row = tbl.find_all('th', scope='col')
    for col in header_row:
        column.append(col.get_text().strip().replace('\n', ''))
column

# %%
wiki_data = []
film_names = []
for tbl in table[:7]:
    rows = tbl.find_all('th', scope='row')
    for row in rows:
        film_names.append(row.get_text().replace('\n', ''))
    for row in rows:
        data = row.find_next_siblings('td')
        text = [i.get_text().replace('\n', '').replace('\xa0', ' ') for i in data]
        text = [re.sub(r'\(.*?\)', '', t) for t in text]  # Remove hidden date part
        wiki_data.append(text)

# Append film names to the corresponding wiki_data sublists
for i, film_name in enumerate(film_names):
    wiki_data[i].insert(0, film_name)

# Ensure each list in wiki_data has exactly 5 elements
for row in wiki_data:
    while len(row) < len(column):
        row.append(None)  # Append None for missing values
    while len(row) > len(column):
        row.pop()  # Remove extra elements

# Create DataFrame with the correct shape
wiki_data_df = pd.DataFrame(wiki_data, columns=column)
wiki_data_df

# %% [markdown]
# Cleaning & Modifying the Pandas Dataframe

# %%
# Define new colum names
new_column_names = {
    'Film[30]': 'film_name',
    'U.S. release date': 'us_release_date',
    'Director': 'director_name',
    'Screenwriter(s)': 'screen_writer',
    'Producer(s)': 'producers'
}

# Rename columns
wiki_data_df.rename(columns=new_column_names, inplace=True)

# Forward fill missing screen_writer values
wiki_data_df['screen_writer'] = wiki_data_df['screen_writer'].ffill()

# Forward fill missing producers values
wiki_data_df['producers'] = wiki_data_df['producers'].ffill()

# Remove numbers in square brackets from all columns
wiki_data_df.replace(to_replace=r'\[\d+\]', value='', regex=True, inplace=True)

# Convert 'us_release_date' to datetime
# wiki_data_df['us_release_date'] = pd.to_datetime(wiki_data_df['us_release_date'])

wiki_data_df.tail(10)

# %% [markdown]
# Getting OMDB API Data

# %%
# Load environment variables from .env file in the current directory
load_dotenv()
# Access the environment variables
api_key = os.getenv('API_KEY')
response_list = []
for film_name in wiki_data_df['film_name']:
    url = f'http://www.omdbapi.com/?t={film_name}&apikey={api_key}'
    response = requests.get(url)
    response_list.append(response.json())
response_list

# %% [markdown]
# Cleaning and making a OMDB Dataframe

# %%
for i in response_list:
    if i.get('Error') == 'Movie not found!':
        i.pop('Error', None)

omdb_data_df = pd.DataFrame(response_list)

# Select only the columns you want to keep
columns_to_keep = ['Title', 'Rated', 'Released', 'Runtime', 'Genre', 'Actors', 'Awards', 'imdbRating', 'BoxOffice', 'Type']
omdb_data_df = omdb_data_df[columns_to_keep]

new_column_names = {
    'Title': 'film_name',
    'Rated': 'rated',
    'Released': 'release_date',
    'Runtime': 'runtime',
    'Genre': 'genre',
    'Actors': 'actors',
    'Awards': 'awards',
    'imdbRating': 'imdb_rating',
    'BoxOffice': 'box_office_collection',
    'Type': 'type',
}
# Rename columns to merge with wiki_data_df
omdb_data_df.rename(columns=new_column_names, inplace=True)

# Remove rows with null values in the film_name column
omdb_data_df.dropna(subset=['film_name'], inplace=True)

omdb_data_df.head()
# Out:
#                             film_name  rated release_date  runtime  \
# 0                            Iron Man  PG-13  02 May 2008  126 min
# 1                 The Incredible Hulk  PG-13  13 Jun 2008  112 min
# 2                          Iron Man 2  PG-13  07 May 2010  124 min
# 3                                Thor  PG-13  06 May 2011  115 min
# 4  Captain America: The First Avenger  PG-13  22 Jul 2011  124 min
#
#                        genre  \
# 0  Action, Adventure, Sci-Fi
# 1  Action, Adventure, Sci-Fi
# 2             Action, Sci-Fi
# 3            Action, Fantasy
# 4  Action, Adventure, Sci-Fi
#
#                                               actors  \
# 0  Robert Downey Jr., Gwyneth Paltrow, Terrence H...
# 1                 Edward Norton, Liv Tyler, Tim Roth
# 2  Robert Downey Jr., Mickey Rourke, Gwyneth Paltrow
# 3  Chris Hemsworth, Anthony Hopkins, Natalie Portman
# 4       Chris Evans, Hugo Weaving, Samuel L. Jackson
#
#                                               awards imdb_rating  \
# 0  Nominated for 2 Oscars. 24 wins & 73 nominatio...         7.9
# 1                            2 wins & 10 nominations         6.6
# 2  Nominated for 1 Oscar. 7 wins & 45 nominations...         6.9
# 3                            5 wins & 30 nominations         7.0
# 4                            4 wins & 50 nominations         6.9
#
#   box_office_collection   type
# 0          $319,034,126  movie
# 1          $134,806,913  movie
# 2          $312,433,331  movie
# 3          $181,030,624  movie
# 4          $176,654,505  movie

# %%
# Joining the two dataframes to get the final result
final_df = wiki_data_df.merge(omdb_data_df, on='film_name', how='left')
final_df.fillna('N/A', inplace=True)
final_df.to_csv('final_df.csv', index=False)
final_df.tail(20)
# Out:
#                                             film_name     us_release_date  \
# 25                                           Eternals   November 5, 2021
# 26                            Spider-Man: No Way Home  December 17, 2021
# 27        Doctor Strange in the Multiverse of Madness        May 6, 2022
# 28                             Thor: Love and Thunder       July 8, 2022
# 29                     Black Panther: Wakanda Forever  November 11, 2022
# 30                  Ant-Man and the Wasp: Quantumania  February 17, 2023
# 31                     Guardians of the Galaxy Vol. 3        May 5, 2023
# 32                                        The Marvels  November 10, 2023
# 33                               Deadpool & Wolverine      July 26, 2024
# 34                   Captain America: Brave New World  February 14, 2025
# 35                                      Thunderbolts*        May 2, 2025
# 36                    The Fantastic Four: First Steps      July 25, 2025
# 37                                 Avengers: Doomsday        May 1, 2026
# 38            Untitled Spider-Man: No Way Home sequel      July 24, 2026
# 39                              Avengers: Secret Wars        May 7, 2027
# 40                                              Blade                 TBD
# 41                                         Armor Wars                 TBA
# 42                                    Black Panther 3                 TBA
# 43  Untitled Shang-Chi and the Legend of the Ten R...                 TBA
# 44                                Untitled X-Men film                 TBA
#
#             director_name                                      screen_writer  \
# 25             Chloé Zhao  Chloé Zhao and Chloé Zhao & Patrick Burleigh a...
# 26              Jon Watts                       Chris McKenna & Erik Sommers
# 27              Sam Raimi                                    Michael Waldron
# 28          Taika Waititi           Taika Waititi & Jennifer Kaytin Robinson
# 29           Ryan Coogler                     Ryan Coogler & Joe Robert Cole
# 30            Peyton Reed                                      Jeff Loveness
# 31             James Gunn                                        Kevin Feige
# 32            Nia DaCosta  Nia DaCosta and Megan McDonnell and Elissa Kar...
# 33             Shawn Levy  Ryan Reynolds & Rhett Reese & Paul Wernick & Z...
# 34            Julius Onah  Julius Onah & Peter Glanz and Matthew Orton[be...
# 35          Jake Schreier      Eric Pearson and Lee Sung Jin and Joanna Calo
# 36           Matt Shakman  Jeff Kaplan & Ian Springer and Josh Friedman a...
# 37  Anthony and Joe Russo                Michael Waldron and Stephen McFeely
# 38  Destin Daniel Cretton                       Chris McKenna & Erik Sommers
# 39  Anthony and Joe Russo                Michael Waldron and Stephen McFeely
# 40                    TBA                                       Eric Pearson
# 41                    TBA                                      Yassir Lester
# 42                    TBA                                       Ryan Coogler
# 43  Destin Daniel Cretton                  Kevin Feige and Jonathan Schwartz
# 44                    TBA                                                TBA
#
#                                             producers  rated release_date  \
# 25                         Kevin Feige and Nate Moore  PG-13  05 Nov 2021
# 26                         Kevin Feige and Amy Pascal  PG-13  17 Dec 2021
# 27                                        Kevin Feige  PG-13  06 May 2022
# 28                    Kevin Feige and Brad Winderbaum  PG-13  08 Jul 2022
# 29                         Kevin Feige and Nate Moore  PG-13  11 Nov 2022
# 30                  Kevin Feige and Stephen Broussard  PG-13  17 Feb 2023
# 31                  Kevin Feige and Stephen Broussard  PG-13  05 May 2023
# 32                  Kevin Feige and Stephen Broussard  PG-13  10 Nov 2023
# 33  Kevin Feige, Lauren Shuler Donner, Ryan Reynol...    N/A          N/A
# 34                         Kevin Feige and Nate Moore    N/A  14 Feb 2025
# 35                                        Kevin Feige    N/A  02 May 2025
# 36                                        Kevin Feige    N/A  25 Jul 2025
# 37                 Kevin Feige, Anthony and Joe Russo    N/A  01 May 2026
# 38                         Kevin Feige and Amy Pascal    N/A          N/A
# 39                 Kevin Feige, Anthony and Joe Russo    N/A          N/A
# 40                                        Kevin Feige      R  21 Aug 1998
# 41                         Kevin Feige and Nate Moore    N/A          N/A
# 42                         Kevin Feige and Nate Moore    N/A          N/A
# 43                         Kevin Feige and Nate Moore    N/A          N/A
# 44                                        Kevin Feige    N/A          N/A
#
#     runtime                       genre  \
# 25  156 min  Action, Adventure, Fantasy
# 26  148 min  Action, Adventure, Fantasy
# 27  126 min  Action, Adventure, Fantasy
# 28  118 min  Adventure, Comedy, Romance
# 29  161 min    Action, Adventure, Drama
# 30  124 min   Action, Adventure, Comedy
# 31  150 min   Action, Adventure, Comedy
# 32  105 min  Action, Adventure, Fantasy
# 33      N/A                         N/A
# 34      N/A   Action, Adventure, Sci-Fi
# 35      N/A    Action, Adventure, Crime
# 36    2 min   Action, Adventure, Sci-Fi
# 37      N/A   Action, Adventure, Sci-Fi
# 38      N/A                         N/A
# 39      N/A                         N/A
# 40  120 min      Action, Horror, Sci-Fi
# 41      N/A                         N/A
# 42      N/A                         N/A
# 43      N/A                         N/A
# 44      N/A                         N/A
#
#                                                actors  \
# 25         Gemma Chan, Richard Madden, Angelina Jolie
# 26         Tom Holland, Zendaya, Benedict Cumberbatch
# 27  Benedict Cumberbatch, Elizabeth Olsen, Chiwete...
# 28   Chris Hemsworth, Natalie Portman, Christian Bale
# 29       Letitia Wright, Lupita Nyong'o, Danai Gurira
# 30       Paul Rudd, Evangeline Lilly, Michael Douglas
# 31        Chris Pratt, Chukwudi Iwuji, Bradley Cooper
# 32          Brie Larson, Teyonah Parris, Iman Vellani
# 33                                                N/A
# 34             Rosa Salazar, Harrison Ford, Liv Tyler
# 35       Florence Pugh, Sebastian Stan, Lewis Pullman
# 36          Pedro Pascal, Vanessa Kirby, Joseph Quinn
# 37          Pedro Pascal, Joseph Quinn, Vanessa Kirby
# 38                                                N/A
# 39                                                N/A
# 40   Wesley Snipes, Stephen Dorff, Kris Kristofferson
# 41                                                N/A
# 42                                                N/A
# 43                                                N/A
# 44                                                N/A
#
#                                                awards imdb_rating  \
# 25                            7 wins & 18 nominations         6.3
# 26  Nominated for 1 Oscar. 35 wins & 71 nomination...         8.2
# 27                           10 wins & 30 nominations         6.9
# 28                            3 wins & 22 nominations         6.2
# 29       Won 1 Oscar. 50 wins & 175 nominations total         6.7
# 30                                     14 nominations         6.0
# 31  Nominated for 1 Oscar. 11 wins & 88 nomination...         7.9
# 32                            4 wins & 11 nominations         5.5
# 33                                                N/A         N/A
# 34                                                N/A         N/A
# 35                                                N/A         N/A
# 36                                                N/A         N/A
# 37                                                N/A         N/A
# 38                                                N/A         N/A
# 39                                                N/A         N/A
# 40                      5 wins & 11 nominations total         7.1
# 41                                                N/A         N/A
# 42                                                N/A         N/A
# 43                                                N/A         N/A
# 44                                                N/A         N/A
#
#    box_office_collection   type
# 25          $164,870,234  movie
# 26          $814,866,759  movie
# 27          $411,331,607  movie
# 28          $343,256,830  movie
# 29          $453,829,060  movie
# 30          $214,504,909  movie
# 31          $358,995,815  movie
# 32           $84,500,223  movie
# 33                   N/A    N/A
# 34                   N/A  movie
# 35                   N/A  movie
# 36                   N/A  movie
# 37                   N/A  movie
# 38                   N/A    N/A
# 39                   N/A    N/A
# 40           $70,087,718  movie
# 41                   N/A    N/A
# 42                   N/A    N/A
# 43                   N/A    N/A
# 44                   N/A    N/A
